# %%
import random

r= int(input("Selecione o jogador:"))
x=21

def retirar(x,y):
         return x-y
        
def sub(y):
    return 5-y

def men(a,z):
    return 5-a-z

def menos(a,z):
    return 10-a-z

def soma(x,y):
    return x+y



z=random.randint(1,4)


    



if r==1:
    print("Você é o jogador 1!")
    while x>1:
        y=int(input("Retire de 1 a 4 palitos"))
        if y>4:
            print("Escolha um valor de 1 a 4 ")
        else:
            print(retirar(x,y))
            print("Jogada do Computador: ",sub(y))
            print("Número de palitos restantes: ",x-y-sub(y))
            x=x-sub(y)-y
            
    else :
        print("O jogador 2 ganhou!")
        

        
            
if r==2 :
    z=random.randint(1,4)
    print("Você é o jogador 2!")
    print("Jogada do computador: ",z)
    contadoreu=0
    contadorpc=1
    x=x-z
    x>=0
    while x>1:
        a=int(input("Retire de 1 a 4 palitos"))
        contadoreu=contadoreu+1
        if a+z<5:
            print("Jogada do computador: ",men(a,z))
            print("Número de palitos restantes: ",x-a-men(a,z))
            z<x-a-men(a,z)
            x=x-a-z
            contadorpc=contadorpc+1
        
            
        if soma(a,z)>5:
            print("Jogada do computador: ",menos(a,z))
            print("Número de palitos restantes: ",x-z-menos(a,z))
            z<x-z-menos(a,z)
            x=x-a-z
            contadorpc=contadorpc+1

        if soma(a,z)==5:
            print("Jogada do computador: ",z)
            print("Número de palitos restantes: ",x-z-menos(a,z))
            z<x-z-menos(a,z)
            x=x-a-z
            contadorpc=contadorpc+1
    else :
        if contadoreu<contadorpc:
            print("O jogador 2 ganhou!")

        if contadorpc<contadoreu:
            print("O jogador 1 ganhou!")
# Out:
# Selecione o jogador:2
# Você é o jogador 2!
# Jogada do computador:  2
# Retire de 1 a 4 palitos1
# Jogada do computador:  2
# Número de palitos restantes:  16
# Retire de 1 a 4 palitos4
# Jogada do computador:  4
# Número de palitos restantes:  10
# Retire de 1 a 4 palitos3
# Jogada do computador:  2
# Número de palitos restantes:  3
# Retire de 1 a 4 palitos1
# Jogada do computador:  2
# Número de palitos restantes:  2
# Retire de 1 a 4 palitos1
# Jogada do computador:  2
# Número de palitos restantes:  -1
# O jogador 2 ganhou!
